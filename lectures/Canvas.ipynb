# %% [markdown]
# # Import funciones personalizadas

# %%
import Canvas_Key

# %% [markdown]
# # Ver cursos para seleccion de ID: curso

# %%
# 1. Conectar con tu usuario
Canvas_Key.select_user("David")
# Out:
# ✓ Usuario seleccionado: David
# ✓ ID del curso asignado: 177387
# ✓ Conectado como: DAVID BASANTES LÓPEZ
# True

# %%
# 2. Ver todos los cursos disponibles
cursos = Canvas_Key.ver_cursos() # filtro_codigo=None
# Out:
# ======================================================================
# 📚 CURSOS DISPONIBLES PARA: DAVID BASANTES LÓPEZ
# 🔍 Filtro aplicado: '2326'
# ======================================================================
#
# 📖 202520.2326 | PROG PARA FIS Y ASTRON
#    ID: 177387
#    Código: PCFI161.202520.2326.TR.AV
#
# ======================================================================
# Total de cursos encontrados: 1
# ======================================================================

# %% [markdown]
# # Subir contenido por usuario

# %%
# 1. Conectar con tu usuario
Canvas_Key.select_user("David")
# Out:
# ✓ Usuario seleccionado: David
# ✓ ID del curso asignado: 177387
# ✓ Conectado como: DAVID BASANTES LÓPEZ
# True

# %%
for i in range(9):
    Canvas_Key.subir_contenido(i+1)
# Out:
# 📌 Usando course_id del usuario: 177387
# ============================================================
# Procesando: Semana 01
# Unidad: UNIDAD I: ELEMENTOS BÁSICOS
# ============================================================
#
# 1. Verificando módulo principal...
#   ✓ Módulo 'Material del curso' encontrado (ID: 1452224)
#
# 2. Analizando estructura actual del módulo...
#   ✓ Unidad 'UNIDAD I: ELEMENTOS BÁSICOS' encontrada en posición 0
#
# 3. Procesando Semana 01...
#   ⚠ Semana 'Semana 01' ya existe. Eliminando versión anterior...
#     ✓ Eliminado: Semana 01
#     ✓ Eliminado: Semana01-P1.pdf
#     ✓ Eliminado: Semana01-P2.pdf
#   ✓ Semana agregada en posición 2
#
# 4. Subiendo archivos...
#   📄 Subiendo: Semana01-P1.pdf...
#     ⚠ Archivo 'Semana01-P1.pdf' ya existe. Eliminando...
#     ✓ Archivo subido (ID: 18067797)
#     ✓ Agregado al módulo: Semana01-P1.pdf
#   📄 Subiendo: Semana01-P2.pdf...
#     ⚠ Archivo 'Semana01-P2.pdf' ya existe. Eliminando...
#     ✓ Archivo subido (ID: 18067799)
#     ✓ Agregado al módulo: Semana01-P2.pdf
#
# 5. Publicando módulo...
#   ✓ Módulo publicado
#
# ============================================================
# ✅ Proceso completado para Semana 01
#    Unidad: UNIDAD I: ELEMENTOS BÁSICOS
#    Archivos subidos: 2/2
#    Estado: PUBLICADO
# ============================================================
# 📌 Usando course_id del usuario: 177387
# ============================================================
# Procesando: Semana 02
# Unidad: UNIDAD I: ELEMENTOS BÁSICOS
# ============================================================
#
# 1. Verificando módulo principal...
#   ✓ Módulo 'Material del curso' encontrado (ID: 1452224)
#
# 2. Analizando estructura actual del módulo...
#   ✓ Unidad 'UNIDAD I: ELEMENTOS BÁSICOS' encontrada en posición 0
#
# 3. Procesando Semana 02...
#   ⚠ Semana 'Semana 02' ya existe. Eliminando versión anterior...
#     ✓ Eliminado: Semana 02
#     ✓ Eliminado: Semana02-P1.pdf
#     ✓ Eliminado: Semana02-P2.pdf
#   ✓ Semana agregada en posición 5
#
# 4. Subiendo archivos...
#   📄 Subiendo: Semana02-P1.pdf...
#     ⚠ Archivo 'Semana02-P1.pdf' ya existe. Eliminando...
#     ✓ Archivo subido (ID: 18067800)
#     ✓ Agregado al módulo: Semana02-P1.pdf
#   📄 Subiendo: Semana02-P2.pdf...
#     ⚠ Archivo 'Semana02-P2.pdf' ya existe. Eliminando...
#     ✓ Archivo subido (ID: 18067801)
#     ✓ Agregado al módulo: Semana02-P2.pdf
#
# 5. Publicando módulo...
#   ✓ Módulo publicado
#
# ============================================================
# ✅ Proceso completado para Semana 02
#    Unidad: UNIDAD I: ELEMENTOS BÁSICOS
#    Archivos subidos: 2/2
#    Estado: PUBLICADO
# ============================================================
# 📌 Usando course_id del usuario: 177387
# ============================================================
# Procesando: Semana 03
# Unidad: UNIDAD II: PROGRAMACIÓN EN PYTHON
# ============================================================
#
# 1. Verificando módulo principal...
#   ✓ Módulo 'Material del curso' encontrado (ID: 1452224)
#
# 2. Analizando estructura actual del módulo...
#   ✓ Unidad 'UNIDAD II: PROGRAMACIÓN EN PYTHON' encontrada en posición 7
#
# 3. Procesando Semana 03...
#   ⚠ Semana 'Semana 03' ya existe. Eliminando versión anterior...
#     ✓ Eliminado: Semana 03
#     ✓ Eliminado: Semana03-P1.pdf
#     ✓ Eliminado: Semana03-P2.pdf
#   ✓ Semana agregada en posición 9
#
# 4. Subiendo archivos...
#   📄 Subiendo: Semana03-P1.pdf...
#     ⚠ Archivo 'Semana03-P1.pdf' ya existe. Eliminando...
#     ✓ Archivo subido (ID: 18067802)
#     ✓ Agregado al módulo: Semana03-P1.pdf
#   📄 Subiendo: Semana03-P2.pdf...
#     ⚠ Archivo 'Semana03-P2.pdf' ya existe. Eliminando...
#     ✓ Archivo subido (ID: 18067803)
#     ✓ Agregado al módulo: Semana03-P2.pdf
#
# 5. Publicando módulo...
#   ✓ Módulo publicado
#
# ============================================================
# ✅ Proceso completado para Semana 03
#    Unidad: UNIDAD II: PROGRAMACIÓN EN PYTHON
#    Archivos subidos: 2/2
#    Estado: PUBLICADO
# ============================================================
# 📌 Usando course_id del usuario: 177387
# ============================================================
# Procesando: Semana 04
# Unidad: UNIDAD II: PROGRAMACIÓN EN PYTHON
# ============================================================
#
# 1. Verificando módulo principal...
#   ✓ Módulo 'Material del curso' encontrado (ID: 1452224)
#
# 2. Analizando estructura actual del módulo...
#   ✓ Unidad 'UNIDAD II: PROGRAMACIÓN EN PYTHON' encontrada en posición 7
#
# 3. Procesando Semana 04...
#   ⚠ Semana 'Semana 04' ya existe. Eliminando versión anterior...
#     ✓ Eliminado: Semana 04
#     ✓ Eliminado: Semana04-P1.pdf
#     ✓ Eliminado: Semana04-P2.pdf
#   ✓ Semana agregada en posición 12
#
# 4. Subiendo archivos...
#   📄 Subiendo: Semana04-P1.pdf...
#     ⚠ Archivo 'Semana04-P1.pdf' ya existe. Eliminando...
#     ✓ Archivo subido (ID: 18067806)
#     ✓ Agregado al módulo: Semana04-P1.pdf
#   📄 Subiendo: Semana04-P2.pdf...
#     ⚠ Archivo 'Semana04-P2.pdf' ya existe. Eliminando...
#     ✓ Archivo subido (ID: 18067807)
#     ✓ Agregado al módulo: Semana04-P2.pdf
#
# 5. Publicando módulo...
#   ✓ Módulo publicado
#
# ============================================================
# ✅ Proceso completado para Semana 04
#    Unidad: UNIDAD II: PROGRAMACIÓN EN PYTHON
#    Archivos subidos: 2/2
#    Estado: PUBLICADO
# ============================================================
# 📌 Usando course_id del usuario: 177387
# ============================================================
# Procesando: Semana 05
# Unidad: UNIDAD II: PROGRAMACIÓN EN PYTHON
# ============================================================
#
# 1. Verificando módulo principal...
#   ✓ Módulo 'Material del curso' encontrado (ID: 1452224)
#
# 2. Analizando estructura actual del módulo...
#   ✓ Unidad 'UNIDAD II: PROGRAMACIÓN EN PYTHON' encontrada en posición 7
#
# 3. Procesando Semana 05...
#   ⚠ Semana 'Semana 05' ya existe. Eliminando versión anterior...
#     ✓ Eliminado: Semana 05
#     ✓ Eliminado: Semana05-P1.pdf
#   ✓ Semana agregada en posición 15
#
# 4. Subiendo archivos...
#   📄 Subiendo: Semana05-P1.pdf...
#     ⚠ Archivo 'Semana05-P1.pdf' ya existe. Eliminando...
#     ✓ Archivo subido (ID: 18067810)
#     ✓ Agregado al módulo: Semana05-P1.pdf
#   ✗ Archivo no encontrado: d:\5) Clases Programacion 1\Clase PCFI 161\pcfi161\lectures\Semana05\Semana05-P2.pdf
#
# 5. Publicando módulo...
#   ✓ Módulo publicado
#
# ============================================================
# ✅ Proceso completado para Semana 05
#    Unidad: UNIDAD II: PROGRAMACIÓN EN PYTHON
#    Archivos subidos: 1/2
#    Estado: PUBLICADO
# ============================================================
# 📌 Usando course_id del usuario: 177387
# ============================================================
# Procesando: Semana 06
# Unidad: UNIDAD III: CONTROLADORES Y ARREGLOS
# ============================================================
#
# 1. Verificando módulo principal...
#   ✓ Módulo 'Material del curso' encontrado (ID: 1452224)
#
# 2. Analizando estructura actual del módulo...
#   ✓ Unidad 'UNIDAD III: CONTROLADORES Y ARREGLOS' encontrada en posición 16
#
# 3. Procesando Semana 06...
#   ⚠ Semana 'Semana 06' ya existe. Eliminando versión anterior...
#     ✓ Eliminado: Semana 06
#     ✓ Eliminado: Semana06-P1.pdf
#     ✓ Eliminado: Semana06-P2.pdf
#   ✓ Semana agregada en posición 18
#
# 4. Subiendo archivos...
#   📄 Subiendo: Semana06-P1.pdf...
#     ⚠ Archivo 'Semana06-P1.pdf' ya existe. Eliminando...
#     ✓ Archivo subido (ID: 18067812)
#     ✓ Agregado al módulo: Semana06-P1.pdf
#   📄 Subiendo: Semana06-P2.pdf...
#     ⚠ Archivo 'Semana06-P2.pdf' ya existe. Eliminando...
#     ✓ Archivo subido (ID: 18067815)
#     ✓ Agregado al módulo: Semana06-P2.pdf
#
# 5. Publicando módulo...
#   ✓ Módulo publicado
#
# ============================================================
# ✅ Proceso completado para Semana 06
#    Unidad: UNIDAD III: CONTROLADORES Y ARREGLOS
#    Archivos subidos: 2/2
#    Estado: PUBLICADO
# ============================================================
# 📌 Usando course_id del usuario: 177387
# ============================================================
# Procesando: Semana 07
# Unidad: UNIDAD IV: EL CICLO FOR, GRÁFICAS
# ============================================================
#
# 1. Verificando módulo principal...
#   ✓ Módulo 'Material del curso' encontrado (ID: 1452224)
#
# 2. Analizando estructura actual del módulo...
#   ✓ Unidad 'UNIDAD IV: EL CICLO FOR, GRÁFICAS' encontrada en posición 20
#
# 3. Procesando Semana 07...
#   ⚠ Semana 'Semana 07' ya existe. Eliminando versión anterior...
#     ✓ Eliminado: Semana 07
#     ✓ Eliminado: Semana07-P1.pdf
#     ✓ Eliminado: Semana07-P2.pdf
#   ✓ Semana agregada en posición 22
#
# 4. Subiendo archivos...
#   📄 Subiendo: Semana07-P1.pdf...
#     ⚠ Archivo 'Semana07-P1.pdf' ya existe. Eliminando...
#     ✓ Archivo subido (ID: 18067820)
#     ✓ Agregado al módulo: Semana07-P1.pdf
#   📄 Subiendo: Semana07-P2.pdf...
#     ⚠ Archivo 'Semana07-P2.pdf' ya existe. Eliminando...
#     ✓ Archivo subido (ID: 18067821)
#     ✓ Agregado al módulo: Semana07-P2.pdf
#
# 5. Publicando módulo...
#   ✓ Módulo publicado
#
# ============================================================
# ✅ Proceso completado para Semana 07
#    Unidad: UNIDAD IV: EL CICLO FOR, GRÁFICAS
#    Archivos subidos: 2/2
#    Estado: PUBLICADO
# ============================================================
# 📌 Usando course_id del usuario: 177387
# ============================================================
# Procesando: Semana 08
# Unidad: UNIDAD IV: EL CICLO FOR, GRÁFICAS
# ============================================================
#
# 1. Verificando módulo principal...
#   ✓ Módulo 'Material del curso' encontrado (ID: 1452224)
#
# 2. Analizando estructura actual del módulo...
#   ✓ Unidad 'UNIDAD IV: EL CICLO FOR, GRÁFICAS' encontrada en posición 23
#
# 3. Procesando Semana 08...
#   ⚠ Semana 'Semana 08' ya existe. Eliminando versión anterior...
#     ✓ Eliminado: Semana 08
#     ✓ Eliminado: Semana08-P1.pdf
#     ✓ Eliminado: Semana08-P2.pdf
#   ✓ Semana agregada en posición 25
#
# 4. Subiendo archivos...
#   📄 Subiendo: Semana08-P1.pdf...
#     ⚠ Archivo 'Semana08-P1.pdf' ya existe. Eliminando...
#     ✓ Archivo subido (ID: 18067825)
#     ✓ Agregado al módulo: Semana08-P1.pdf
#   📄 Subiendo: Semana08-P2.pdf...
#     ⚠ Archivo 'Semana08-P2.pdf' ya existe. Eliminando...
#     ✓ Archivo subido (ID: 18067827)
#     ✓ Agregado al módulo: Semana08-P2.pdf
#
# 5. Publicando módulo...
#   ✓ Módulo publicado
#
# ============================================================
# ✅ Proceso completado para Semana 08
#    Unidad: UNIDAD IV: EL CICLO FOR, GRÁFICAS
#    Archivos subidos: 2/2
#    Estado: PUBLICADO
# ============================================================
# 📌 Usando course_id del usuario: 177387
# ============================================================
# Procesando: Semana 09
# Unidad: UNIDAD IV: EL CICLO FOR, GRÁFICAS
# ============================================================
#
# 1. Verificando módulo principal...
#   ✓ Módulo 'Material del curso' encontrado (ID: 1452224)
#
# 2. Analizando estructura actual del módulo...
#   ✓ Unidad 'UNIDAD IV: EL CICLO FOR, GRÁFICAS' encontrada en posición 26
#
# 3. Procesando Semana 09...
#   ⚠ Semana 'Semana 09' ya existe. Eliminando versión anterior...
#     ✓ Eliminado: Semana 09
#     ✓ Eliminado: Semana09-P1.pdf
#     ✓ Eliminado: Semana09-P2.pdf
#   ✓ Semana agregada en posición 28
#
# 4. Subiendo archivos...
#   📄 Subiendo: Semana09-P1.pdf...
#     ⚠ Archivo 'Semana09-P1.pdf' ya existe. Eliminando...
#     ✓ Archivo subido (ID: 18067832)
#     ✓ Agregado al módulo: Semana09-P1.pdf
#   📄 Subiendo: Semana09-P2.pdf...
#     ⚠ Archivo 'Semana09-P2.pdf' ya existe. Eliminando...
#     ✓ Archivo subido (ID: 18067833)
#     ✓ Agregado al módulo: Semana09-P2.pdf
#
# 5. Publicando módulo...
#   ✓ Módulo publicado
#
# ============================================================
# ✅ Proceso completado para Semana 09
#    Unidad: UNIDAD IV: EL CICLO FOR, GRÁFICAS
#    Archivos subidos: 2/2
#    Estado: PUBLICADO
# ============================================================
