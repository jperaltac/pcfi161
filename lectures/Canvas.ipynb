# %% [markdown]
# # Import funciones personalizadas

# %%
import Canvas_Key

# %%
# 1. Conectar con tu usuario
Canvas_Key.select_user("Fabrizzio")
# Out:
# ✓ Usuario seleccionado: Fabrizzio
# ✓ ID del curso asignado: 177370
# ✓ Conectado como: FABRIZIO BUGINI JARA
# ✓ Conectado como: FABRIZIO BUGINI JARA
# True

# %%
# 1. Conectar con tu usuario
Canvas_Key.select_user("David")
# Out:
# ✓ Usuario seleccionado: David
# ✓ ID del curso asignado: 177387
# ✓ Conectado como: DAVID BASANTES LÓPEZ
# ✓ Conectado como: DAVID BASANTES LÓPEZ
# True

# %% [markdown]
# # Gestion de modulos

# %% [markdown]
# ## Ver modulos

# %%
# Ver todos los módulos con su contenido
Canvas_Key.ver_modulos()
# Out:
# 📌 Usando course_id del usuario: 177370
# ...
# 📚 MÓDULOS DEL CURSO (ID: 177370)
# ...
#
# [1] ✅ | ID: 1455587 | Material del curso
#   ↳ [Pos=1] 📌 UNIDAD I: ELEMENTOS BÁSICOS | ID: 9828768 | Publicado: ✅ | Indent: 0
#     ↳ [Pos=2] 📌 Semana 01 | ID: 9828769 | Publicado: ✅ | Indent: 1
#       ↳ [Pos=3] 📄 Semana01-P1.pdf | ID: 9828770 | Publicado: ✅ | Indent: 2
#       ↳ [Pos=4] 📄 Semana01-P2.pdf | ID: 9828771 | Publicado: ✅ | Indent: 2
#     ↳ [Pos=5] 📌 Semana 02 | ID: 9828772 | Publicado: ✅ | Indent: 1
#       ↳ [Pos=6] 📄 Semana02-P1.pdf | ID: 9828773 | Publicado: ✅ | Indent: 2
#       ↳ [Pos=7] 📄 Semana02-P2.pdf | ID: 9828774 | Publicado: ✅ | Indent: 2
#   ↳ [Pos=8] 📌 UNIDAD II: PROGRAMACIÓN EN PYTHON | ID: 9828775 | Publicado: ✅ | Indent: 0
#     ↳ [Pos=9] 📌 Semana 03 | ID: 9828776 | Publicado: ✅ | Indent: 1
#       ↳ [Pos=10] 📄 Semana03-P1.pdf | ID: 9828777 | Publicado: ✅ | Indent: 2
#       ↳ [Pos=11] 📄 Semana03-P2.pdf | ID: 9828778 | Publicado: ✅ | Indent: 2
# ...

# %%
# Ver solo módulos sin items
Canvas_Key.ver_modulos(mostrar_items=False)
# Out:
# 📌 Usando course_id del usuario: 177370
# ...
# 📚 MÓDULOS DEL CURSO (ID: 177370)
# ...
#
# [1] ✅ | ID: 1455587 | Material del curso
#
# [2] ❌ | ID: 1454673 | Solemnes
#
# [3] ✅ | ID: 1290903 | Información General
#
# [4] ✅ | ID: 1290908 | Directrices y Reglamentos
#
# [5] ✅ | ID: 1290913 | Integridad Académica
#
# [6] ✅ | ID: 1290925 | Preparando mi Año Académico
#
# [7] ✅ | ID: 1290935 | Hábitos, Planificación y Establecimiento Objetivos
#
# [8] ✅ | ID: 1290936 | Estrategias y Técnicas de Estudio
#
# [9] ✅ | ID: 1290944 | Preparación de Evaluaciones
#
# [10] ✅ | ID: 1290957 | Manejo de la Ansiedad y Estrés Académico
#
# [11] ❌ | ID: 1290983 | Evaluaciones
#
# [12] ✅ | ID: 1359318 | Semana 1
#
# [13] ✅ | ID: 1368033 | Semana 2
#
# [14] ✅ | ID: 1387541 | Semana 3
#
# [15] ✅ | ID: 1390230 | Semana 5
#
# [16] ✅ | ID: 1397912 | Solemne 1
#
# [17] ✅ | ID: 1400807 | Semana 6
#
# [18] ✅ | ID: 1432690 | Semana 7
#
# [19] ✅ | ID: 1441308 | Semana 8
#
# [20] ✅ | ID: 1451117 | Semana 9
#
# ...

# %% [markdown]
# ## Modificar modulo

# %%
# Cambiar múltiples propiedades
Canvas_Key.mover_modulo(module_id=1454673  , publicado=False) # , nueva_posicion=20, nuevo_nombre="Material del curso old"
# Out:
# 📌 Usando course_id del usuario: 177370
# ...
# � MODIFICANDO MÓDULO
# Curso ID: 177370
# Módulo ID: 1454673
# ...
#
# 1. Buscando módulo...
#   ✓ Módulo encontrado: 'Solemnes'
#     Posición actual: 2
#     Publicado actual: True
#
# 2. Preparando cambios...
#   • Estado: Publicado → No publicado
#
# 3. Aplicando cambios...
#   ✓ Cambios aplicados exitosamente
#
# 4. Verificando cambios...
#   ✓ Nombre actual: Solemnes
#   ✓ Posición actual: 2
#   ✓ Publicado actual: False
#
# ...
# ✅ Módulo modificado exitosamente
# ...
# True

# %% [markdown]
# ## Modificar contenido de un módulo específico

# %%
# Ver contenido de un módulo específico
Canvas_Key.ver_contenido_modulo(module_id=1455587 )
# Out:
# 📌 Usando course_id del usuario: 177370
# ...
# 📦 CONTENIDO DEL MÓDULO: Material del curso
# ID: 1455587 | Posición: 1 | Publicado: ✅
# ...
#
# Total de items: 48
#
# 0   ↳ [1] ✅ | 📌 | ID: 9828768 | UNIDAD I: ELEMENTOS BÁSICOS
# 1     ↳ [2] ✅ | 📌 | ID: 9828769 | Semana 01
# 2       ↳ [3] ✅ | 📄 | ID: 9828770 | Semana01-P1.pdf
# 2       ↳ [4] ✅ | 📄 | ID: 9828771 | Semana01-P2.pdf
# 1     ↳ [5] ✅ | 📌 | ID: 9828772 | Semana 02
# 2       ↳ [6] ✅ | 📄 | ID: 9828773 | Semana02-P1.pdf
# 2       ↳ [7] ✅ | 📄 | ID: 9828774 | Semana02-P2.pdf
# 0   ↳ [8] ✅ | 📌 | ID: 9828775 | UNIDAD II: PROGRAMACIÓN EN PYTHON
# 1     ↳ [9] ✅ | 📌 | ID: 9828776 | Semana 03
# 2       ↳ [10] ✅ | 📄 | ID: 9828777 | Semana03-P1.pdf
# 2       ↳ [11] ✅ | 📄 | ID: 9828778 | Semana03-P2.pdf
# 1     ↳ [12] ✅ | 📌 | ID: 9828779 | Semana 04
# 2       ↳ [13] ✅ | 📄 | ID: 9828780 | Semana04-P1.pdf
# 2       ↳ [14] ✅ | 📄 | ID: 9828781 | Semana04-P2.pdf
# 1     ↳ [15] ✅ | 📌 | ID: 9828782 | Semana 05
# ...

# %%
# Mover un item dentro del módulo
Canvas_Key.mover_item_modulo(module_id=1455587, item_id=9829700 , nueva_posicion=60)
# Out:
# ...
# 🔄 MOVIENDO ITEM DENTRO DEL MÓDULO: Material del curso
# ...
#
# Item encontrado: Semana11-P1 (3).pdf
# Posición actual: 34 → Nueva posición: 60
# ✅ Item movido exitosamente
# True

# %%
# Modificar propiedades de un item
Canvas_Key.modificar_item_modulo(module_id=1455587, item_id=9829700, indent=2, publicado=False) # , nuevo_titulo="Nuevo nombre"
# Out:
# ...
# 🔧 MODIFICANDO ITEM DEL MÓDULO: Material del curso
# ...
#
# Item encontrado: Semana11-P1 (3).pdf
# • Estado: Publicado → No publicado
# • Sangría: 0 → 2
# ❌ Error al modificar el item: {"message":"item can't be unpublished"}
# False

# %% [markdown]
# # Ordenar modulo

# %%
Canvas_Key.ordenar_modulo()
# Out:
# 📌 Usando course_id del usuario: 177370
# ...
# 🔧 ORDENAMIENTO MANUAL DE MÓDULO
# Curso ID: 177370
# Módulo: Material del curso
# ...
#
# 1. Buscando módulo...
#   ✓ Módulo 'Material del curso' encontrado (ID: 1455587)
#
# 🔄 Verificando y ordenando estructura completa...
#   📋 Comparando estructura actual con estructura base...
#   🔧 Reposicionando 4 items...
#     ✓ Unidad: UNIDAD V: CLASES & ANALISIS DE DATOS → posición 35
#     ✓   Semana: Semana 11 | np.polyfit y análisis de residuos → posición 36
#     ✓     Archivo: Semana11-P1.pdf → posición 37
#     ✓     Archivo: Semana11-P2.pdf → posición 38
#   ✓ Estructura completamente ordenada según base
#
# ...
# ✅ Módulo ordenado correctamente
# ...
# True

# %% [markdown]
# # Subir contenido por usuario

# %%
Canvas_Key.subir_contenido(15)
# Out:
# 📌 Usando course_id del usuario: 177387
# ...
# 📤 SUBIENDO CONTENIDO A CANVAS
# Semana: Semana 15 | Repaso pre-solemnes
# Unidad: UNIDAD VI: ALGORITMOS, & PERFORMANCE
# Archivos: Semana15-P1.pdf y Semana15-P2.pdf
# ...
#
# 1. Verificando módulo principal...
#   ✓ Módulo 'Material del curso' encontrado (ID: 1452224)
#
# 🔄 Verificando y ordenando estructura completa...
#   📋 Comparando estructura actual con estructura base...
#   🔧 Reposicionando 7 items...
#     ✓ Unidad: UNIDAD III: CONTROLADORES Y ARREGLOS → posición 18
#     ✓   Semana: Semana 06 → posición 19
#     ✓     Archivo: Semana06-P1.pdf → posición 20
#     ✓     Archivo: Semana06-P2.pdf → posición 21
#     ✓   Semana: Semana 07 → posición 22
#     ✓     Archivo: Semana07-P1.pdf → posición 23
#     ✓     Archivo: Semana07-P2.pdf → posición 24
#   ✓ Estructura completamente ordenada según base
#
# 2. Analizando estructura actual del módulo...
#   ✓ Unidad 'UNIDAD VI: ALGORITMOS, & PERFORMANCE' encontrada en posición 39
#
# ...

# %%
lista = [11,12,13,14,15]
for i in lista:
    Canvas_Key.subir_contenido(i)
# Out:
# 📌 Usando course_id del usuario: 177370
# ...
# 📤 SUBIENDO CONTENIDO A CANVAS
# Semana: Semana 11 | np.polyfit y análisis de residuos
# Unidad: UNIDAD V: CLASES & ANALISIS DE DATOS
# Archivos: Semana11-P1.pdf y Semana11-P2.pdf
# ...
#
# 1. Verificando módulo principal...
#   ✓ Módulo 'Material del curso' encontrado (ID: 1455587)
#
# 🔄 Verificando y ordenando estructura completa...
#   📋 Comparando estructura actual con estructura base...
#   🔧 Reposicionando 1 items...
#     ✓ Unidad: UNIDAD V: CLASES & ANALISIS DE DATOS → posición 35
#   ✓ Estructura completamente ordenada según base
#
# 2. Analizando estructura actual del módulo...
#   ✓ Unidad 'UNIDAD V: CLASES & ANALISIS DE DATOS' encontrada en posición 33
#
# 3. Procesando 'Semana 11 | np.polyfit y análisis de residuos'...
#   ⚠ 'Semana 11' detectada. Eliminando versión anterior...
#   🗑️ Eliminando 3 items antiguos...
#     ✓ Eliminado: Semana 11
#     ✓ Eliminado: Semana11-P1.pdf
#     ✓ Eliminado: Semana11-P2.pdf
# ...

# %% [markdown]
# # Solemnes

# %% [markdown]
# ## Modulo Solemnes

# %%
# Crear Solemne 2 en el grupo "Notas de presentación"
Canvas_Key.crear_modulo_solemne(
    numero_solemne=3,
    fecha_inicio="27-11-2025 14:00",
    fecha_hasta="27-11-2025 16:00",
)
# Out:
# 📌 Usando course_id del usuario: 177370
# ...
# 📋 Creando/Actualizando Solemne 3
# Curso ID: 177370
# 📅 Disponible desde: 27-11-2025 14:00
# 📅 Disponible hasta: 27-11-2025 16:00
# ...
#
# 1. Verificando módulo principal 'Solemnes'...
#   ✓ Módulo 'Solemnes' encontrado (ID: 1454673)
#
# 2. Verificando grupo de calificaciones 'Nota de presentación'...
#   ✓ Grupo de calificaciones encontrado (ID: 673509)
#
# 3. Creando examen 'Solemne 3'...
#   📅 Fecha de disponibilidad: 27-11-2025 14:00
#   📅 Fecha de entrega: 27-11-2025 16:00
#   ⚠ Examen 'Solemne 3' ya existe. Eliminando...
#     ✓ Examen eliminado
#   ✓ Examen creado: Solemne 3 (ID: 1328549)
#
# 4. Buscando archivo PDF del Solemne 3...
#   ✓ Archivo PDF encontrado: Solemne 3.pdf
#   ⚠ Archivo 'Solemne 3.pdf' ya existe en Canvas. Eliminando...
#     ✓ Archivo eliminado
#   📤 Subiendo PDF a Canvas...
#   ✓ PDF subido exitosamente (ID: 18380667)
#   📅 Aplicando fecha de disponibilidad al PDF: 27-11-2025 14:00
# ...

# %%
# Crear Solemne 2 en el grupo "Notas de presentación"
Canvas_Key.crear_modulo_solemne(
    numero_solemne=2,
    fecha_inicio="30-10-2025 13:55",
    fecha_hasta="30-10-2025 17:00",
)
# Out:
# 📌 Usando course_id del usuario: 177370
# ...
# 📋 Creando/Actualizando Solemne 2
# Curso ID: 177370
# 📅 Disponible desde: 30-10-2025 13:55
# 📅 Disponible hasta: 30-10-2025 17:00
# ...
#
# 1. Verificando módulo principal 'Solemnes'...
#   ✓ Módulo 'Solemnes' encontrado (ID: 1454673)
#
# 2. Verificando grupo de calificaciones 'Nota de presentación'...
#   ✓ Grupo de calificaciones encontrado (ID: 673509)
#
# 3. Creando examen 'Solemne 2'...
#   📅 Fecha de disponibilidad: 30-10-2025 13:55
#   📅 Fecha de entrega: 30-10-2025 17:00
#   ⚠ Examen 'Solemne 2' ya existe. Eliminando...
#     ✓ Examen eliminado
#   ✓ Examen creado: Solemne 2 (ID: 1319544)
#
# 4. Buscando archivo PDF del Solemne 2...
#   ✓ Archivo PDF encontrado: Solemne 2.pdf
#   ⚠ Archivo 'Solemne 2.pdf' ya existe en Canvas. Eliminando...
#     ✓ Archivo eliminado
#   📤 Subiendo PDF a Canvas...
#   ✓ PDF subido exitosamente (ID: 18144690)
#   📅 Aplicando fecha de disponibilidad al PDF: 30-10-2025 13:55
# ...

# %%
# Crear Examen Final en el grupo "Notas de presentación"
Canvas_Key.crear_modulo_examen(
    fecha_inicio="10-12-2025 10:20",
    fecha_hasta="10-12-2025 12:55",
)
# Out:
# 📌 Usando course_id del usuario: 177370
# ...
# 📋 Creando/Actualizando Examen Final
# Curso ID: 177370
# 📅 Disponible desde: 10-12-2025 10:20
# 📅 Disponible hasta: 10-12-2025 12:55
# ...
#
# 1. Verificando módulo principal 'Solemnes'...
# ...
# 📋 Creando/Actualizando Examen Final
# Curso ID: 177370
# 📅 Disponible desde: 10-12-2025 10:20
# 📅 Disponible hasta: 10-12-2025 12:55
# ...
#
# 1. Verificando módulo principal 'Solemnes'...
#   ✓ Módulo 'Solemnes' encontrado (ID: 1454673)
#
# 2. Verificando grupo de calificaciones 'Nota de presentación'...
#   ✓ Grupo de calificaciones encontrado (ID: 673509)
#
# 3. Creando examen 'Examen'...
#   📅 Fecha de disponibilidad: 10-12-2025 10:20
#   📅 Fecha de entrega: 10-12-2025 12:55
#   ✓ Módulo 'Solemnes' encontrado (ID: 1454673)
#
# 2. Verificando grupo de calificaciones 'Nota de presentación'...
#   ✓ Grupo de calificaciones encontrado (ID: 673509)
#
# 3. Creando examen 'Examen'...
#   📅 Fecha de disponibilidad: 10-12-2025 10:20
# ...

# %%
print("")

# %% [markdown]
# ## Actualizar Fechas Solemne

# %%
Canvas_Key.actualizar_fechas_solemne(
    numero_solemne=2,
    fecha_inicio="30-10-2025 13:55",
    fecha_hasta="30-10-2025 17:00",
)
# Out:
# 🔄 Actualizando fechas de 'Solemne 2'...
# 💡 NOTA: Las fechas se aplican recreando el solemne con las nuevas fechas
# ...
# 📋 Creando/Actualizando Solemne 2
# Curso ID: 177370
# 📅 Disponible desde: 30-10-2025 13:55
# 📅 Disponible hasta: 30-10-2025 17:00
# ...
#
# 1. Verificando módulo principal 'Solemnes'...
#   ✓ Módulo 'Solemnes' encontrado (ID: 1454673)
#
# 2. Verificando grupo de calificaciones 'Nota de presentación'...
#   ✓ Grupo de calificaciones encontrado (ID: 673509)
#
# 3. Creando examen 'Solemne 2'...
#   📅 Fecha de disponibilidad: 30-10-2025 13:55
#   📅 Fecha de entrega: 30-10-2025 17:00
#   ⚠ Examen 'Solemne 2' ya existe. Eliminando...
#     ✓ Examen eliminado
#   ✓ Examen creado: Solemne 2 (ID: 1319543)
#
# 4. Buscando archivo PDF del Solemne 2...
# ❌ Error al actualizar fechas: cannot access local variable 'base_path' where it is not associated with a value
# False

# %%
Canvas_Key.actualizar_fechas_solemne(
    numero_solemne=2,
    fecha_inicio="07-11-2025 13:00",
    fecha_hasta="07-11-2025 15:00",
)
# Out:
# 🔄 Actualizando fechas de 'Solemne 2'...
# 💡 NOTA: Las fechas se aplican recreando el solemne con las nuevas fechas
# ...
# 📋 Creando/Actualizando Solemne 2
# Curso ID: 177387
# 📅 Disponible desde: 07-11-2025 13:00
# 📅 Disponible hasta: 07-11-2025 15:00
# ...
#
# 1. Verificando módulo principal 'Solemnes'...
#   ✓ Módulo 'Solemnes' encontrado (ID: 1397814)
#
# 2. Verificando grupo de calificaciones 'Nota de presentación'...
#   ✓ Grupo de calificaciones encontrado (ID: 673508)
#
# 3. Creando examen 'Solemne 2'...
#   📅 Fecha de disponibilidad: 07-11-2025 13:00
#   📅 Fecha de entrega: 07-11-2025 15:00
#   ⚠ Examen 'Solemne 2' ya existe. Eliminando...
#     ✓ Examen eliminado
#   ✓ Examen creado: Solemne 2 (ID: 1319443)
#
# 4. Verificando items existentes del módulo...
#
# 5. Agregando examen al módulo en posición 2 (indent=0)...
#   ✓ Examen agregado al módulo: Solemne 2
#
# 6. Publicando módulo...
#   ✓ Módulo publicado
#
# ...
# ✅ Solemne 2 creado/actualizado exitosamente
# ...

# %% [markdown]
# ## Ver estado completo de Solemnes

# %%
Canvas_Key.estado_solemnes()
# Out:
# 📌 Usando course_id del usuario: 177370
# ...
# 📊 ESTADO DEL MÓDULO SOLEMNES
# ...
#
# 1. Buscando módulo 'Solemnes'...
#   ✓ Módulo encontrado (ID: 1454673)
#
# 📦 INFORMACIÓN DEL MÓDULO:
#    Nombre: Solemnes
#    ID: 1454673
#    Posición: 1
#    Publicado: ✅ True
#    📅 Fecha de desbloqueo: Sin restricción
#    📅 Fecha de bloqueo: Sin restricción
#
# 2. Analizando items del módulo...
#
# 📋 ITEMS DEL MÓDULO (1 total):
# ...
#
# [1] Solemne 2
#     ID: 9822324
#     Tipo: Assignment
#     Publicado: ✅ True
#     Posición: 1
#     Indent: 0
#
#     📝 DETALLES DEL EXAMEN:
#        Puntos: 100.0
#        Grupo: Nota de presentación
#        📅 Disponible desde: 30-10-2025 16:55
#        📅 Fecha de entrega: 30-10-2025 20:00
#        Tipos de entrega: online_upload, online_text_entry
#
# ...
# ✅ Análisis completado - 1 items encontrados
# ...
# {'module': {'id': 1454673,
#   'name': 'Solemnes',
#   'published': True,
#   'position': 1,
#   'unlock_at': None,
#   'lock_at': None},
#  'items': [{'id': 9822324,
# ...

# %% [markdown]
# ## Verificar estado de archivo PDF

# %%
# Verificar el estado del archivo PDF con ID específico
file_id = 18144690

# Obtener el curso actual
course = Canvas_Key.canvas.get_course(Canvas_Key.current_course_id)

# Obtener el archivo
pdf_file = course.get_file(file_id)

print("=" * 60)
print(f"📄 INFORMACIÓN DEL ARCHIVO PDF")
print("=" * 60)
print(f"ID: {pdf_file.id}")
print(f"Nombre: {pdf_file.display_name}")
print(f"Tamaño: {pdf_file.size / 1024:.2f} KB")
print(f"URL: {pdf_file.url}")
print()
print("🔒 CONFIGURACIÓN DE PRIVACIDAD:")
print(f"Hidden (oculto): {pdf_file.hidden}")
print(f"Locked (bloqueado): {pdf_file.locked}")
print(f"Visibility: {getattr(pdf_file, 'visibility', 'N/A')}")
print()
print("📅 FECHAS DE DISPONIBILIDAD:")
print(f"Unlock at: {getattr(pdf_file, 'unlock_at', 'N/A')}")
print(f"Lock at: {getattr(pdf_file, 'lock_at', 'N/A')}")
print("=" * 60)
# Out:
# ...
# 📄 INFORMACIÓN DEL ARCHIVO PDF
# ...
# ID: 18144690
# Nombre: Solemne 2.pdf
# Tamaño: 103.51 KB
# URL: https://canvas.unab.cl/files/18144690/download?download_frd=1&verifier=MzHhIfnZvY2iqiCEbXYlxHbjFoPE4Py0ZxJvKAAG
#
# 🔒 CONFIGURACIÓN DE PRIVACIDAD:
# Hidden (oculto): True
# Locked (bloqueado): True
# Visibility: N/A
#
# 📅 FECHAS DE DISPONIBILIDAD:
# Unlock at: 2025-10-30T16:55:00Z
# Lock at: 2025-10-30T20:00:00Z
# ...

# %% [markdown]
# # Organizacion
